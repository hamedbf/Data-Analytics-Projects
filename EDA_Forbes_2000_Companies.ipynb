# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Forbes_2000_top_company_CLNQ11.csv')

# %%
df.head()
# Out:
#    2022 Ranking                         Organization Name  \
# 0             1                        Berkshire Hathaway
# 1             2                                      ICBC
# 2             3  Saudi Arabian Oil Company (Saudi Aramco)
# 3             4                            JPMorgan Chase
# 4             5                   China Construction Bank
#
#                  Industry        Country  Year Founded  \
# 0  Diversified Financials  United States          1939
# 1                 Banking          China          1984
# 2    Oil & Gas Operations   Saudi Arabia          1933
# 3  Diversified Financials  United States          2000
# 4                 Banking          China          2014
#
#                         CEO  Revenue (Billions)  Profits (Billions)  \
# 0     Warren Edward Buffett              276.09               89.80
# 1                    Shu Gu              208.13               54.03
# 2  Amin bin Hasan Al-Nasser              400.38              105.36
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   2022 Ranking             1999 non-null   int64
#  1   Organization Name        1999 non-null   object
#  2   Industry                 1999 non-null   object
#  3   Country                  1999 non-null   object
#  4   Year Founded             1999 non-null   int64
#  5   CEO                      1999 non-null   object
#  6   Revenue (Billions)       1999 non-null   float64
#  7   Profits (Billions)       1999 non-null   float64
#  8   Assets (Billions)        1999 non-null   float64
#  9   Market Value (Billions)  1999 non-null   float64
#  10  Total Employees          1999 non-null   object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 171.9+ KB

# %%
df.describe()
# Out:
#        2022 Ranking  Year Founded  Revenue (Billions)  Profits (Billions)  \
# count   1999.000000   1999.000000         1999.000000         1999.000000
# mean     999.818409   1863.992496           23.886628            2.503167
# std      577.098137    421.815723           40.951362            6.160483
# min        1.000000      0.000000            0.000000          -12.050000
# 25%      500.500000   1919.000000            5.600000            0.590000
# 50%     1000.000000   1971.000000           12.170000            1.060000
# 75%     1499.000000   1996.000000           23.730000            2.270000
# max     1999.000000   2022.000000          572.750000          105.360000
#
#        Assets (Billions)  Market Value (Billions)
# count        1999.000000              1999.000000
# mean          117.176013                38.260675
# std           363.826515               117.233301
# min             0.170000                 0.140000
# ...

# %%
df['Year Founded'].unique()
# Out:
# array([1939, 1984, 1933, 2000, 2014, 1994, 1976, 1979, 1998, 1937, 1975,
#        1929, 1938, 1999, 1907, 1988, 1852, 1983, 1876, 1977, 1962, 1987,
#        1879, 1924, 1919, 1997, 1963, 2004, 1896, 1869, 1865, 1953, 1886,
#        1883, 1849, 1981, 1864, 1866, 1816, 1989, 1909, 1968, 1855, 1952,
#        1973, 1960, 1902, 2005, 1903, 1908, 1837, 1916, 1995, 2013, 1996,
#        1972, 2003, 1868, 1885, 1978, 1850, 1847, 2021, 1872, 1993, 1873,
#        1792, 1875, 1965, 1891, 1832, 1974, 2008, 1923, 1985, 2009, 1911,
#        1862, 1959, 1870, 1982, 1955, 1992, 2020, 1892, 1841, 1817, 1942,
#        1956, 1970, 2002, 2007, 1887, 1888, 1944, 1925, 1947, 1858, 1971,
#        1949, 1910, 1967, 1958, 1880, 1871, 1901, 1831, 1921, 1961, 1991,
#        1912, 1904, 1899, 1917, 1943, 1906, 2006, 1867, 1835, 2001, 1897,
#        1931, 1980, 1964, 1781, 2012, 1836, 1945, 1863, 1966, 1808, 1668,
#        1927, 1920, 1990, 1833, 2017, 1665, 2016, 2010, 1948, 2011, 1969,
# ...

# %%
df[df['Year Founded']==0]['Country'].value_counts() #uncompetent date error #most of them are from China
# Out:
# China             41
# United States     14
# Taiwan             5
# Japan              5
# Sweden             4
# United Kingdom     4
# South Korea        4
# Brazil             3
# Hong Kong          3
# Australia          3
# Israel             2
# Kuwait             1
# Italy              1
# India              1
# Germany            1
# Ireland            1
# Canada             1
# Russia             1
# Greece             1
# Name: Country, dtype: int64

# %%
byCountry= pd.DataFrame(data=df.groupby(['Country']).sum()['Market Value (Billions)'])

# %%
byCountry['Market Value (Billions)'].sort_values(ascending=False).head(10)
# Out:
# Country
# United States     38191.90
# China              6839.22
# Japan              3440.13
# Canada             2868.31
# Saudi Arabia       2809.46
# United Kingdom     2498.35
# France             2210.35
# Switzerland        1968.63
# India              1762.24
# Germany            1512.32
# Name: Market Value (Billions), dtype: float64

# %%
byCountry_mean= pd.DataFrame(data=df.groupby(['Country']).mean()['Market Value (Billions)'])

# %%
byCountry_mean['Market Value (Billions)'].sort_values(ascending=False).head(10)
# Out:
# Country
# Saudi Arabia      175.591250
# United States      65.397089
# Uruguay            49.400000
# Switzerland        49.215750
# Denmark            47.494545
# Canada             44.817344
# France             40.932407
# Ireland            39.329048
# United Kingdom     39.036719
# Australia          37.931000
# Name: Market Value (Billions), dtype: float64

# %%
df.groupby(['Industry'])['Market Value (Billions)'].sum().sort_values(ascending=False).head(10)
# Out:
# Industry
# IT Software & Services             7985.74
# Banking                            6507.19
# Oil & Gas Operations               6454.35
# Drugs & Biotechnology              4842.84
# Diversified Financials             4770.08
# Technology Hardware & Equipment    4460.59
# Retailing                          4230.34
# Food, Drink & Tobacco              3608.99
# Consumer Durables                  3218.04
# Semiconductors                     3145.00
# Name: Market Value (Billions), dtype: float64

# %%
for i in df['Total Employees']:
  if ']' in i:
    i=i[:-1]
    df['Total Employees'].replace(i,i[:-1])

# %%
df.head(61)
# Out:
#     2022 Ranking                         Organization Name  \
# 0              1                        Berkshire Hathaway
# 1              2                                      ICBC
# 2              3  Saudi Arabian Oil Company (Saudi Aramco)
# 3              4                            JPMorgan Chase
# 4              5                   China Construction Bank
# ..           ...                                       ...
# 56            57                                 Santander
# 57            58                  Mitsubishi UFJ Financial
# 58            58                      Taiwan Semiconductor
# 59            60                                Ford Motor
# 60            61          LVMH Moët Hennessy Louis Vuitton
#
#                          Industry        Country  Year Founded  \
# 0          Diversified Financials  United States          1939
# 1                         Banking          China          1984
# 2            Oil & Gas Operations   Saudi Arabia          1933
# ...

# %%
df.groupby(['Industry']).sum()['Market Value (Billions)'].hist()

# %%
df[df['Country']=='United States']['Assets (Billions)'].plot()
df.columns
# Out:
# Index(['2022 Ranking', 'Organization Name', 'Industry', 'Country',
#        'Year Founded', 'CEO', 'Revenue (Billions)', 'Profits (Billions)',
#        'Assets (Billions)', 'Market Value (Billions)', 'Total Employees'],
#       dtype='object')

# %%
df['Country'].nunique()
# Out:
# 57

# %%
sns.pairplot(df)

# %%
sns.jointplot(df['Assets (Billions)'],df['Revenue (Billions)'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.scatter(df['Assets (Billions)'],df['Revenue (Billions)'])

# %%
df[df['Assets (Billions)']>2000]['Revenue (Billions)'].nunique(),df[df['Assets (Billions)']<500]['Revenue (Billions)'].nunique()
# Out:
# (15, 1513)

# %%
df[['Assets (Billions)','Revenue (Billions)','2022 Ranking']].corr()
# Out:
#                     Assets (Billions)  Revenue (Billions)  2022 Ranking
# Assets (Billions)            1.000000            0.338285     -0.336636
# Revenue (Billions)           0.338285            1.000000     -0.511419
# 2022 Ranking                -0.336636           -0.511419      1.000000

# %%
df['Market Value (Billions)'].plot()

# %%
df[df['Market Value (Billions)']<200].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1947 entries, 4 to 1998
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   2022 Ranking             1947 non-null   int64
#  1   Organization Name        1947 non-null   object
#  2   Industry                 1947 non-null   object
#  3   Country                  1947 non-null   object
#  4   Year Founded             1947 non-null   int64
#  5   CEO                      1947 non-null   object
#  6   Revenue (Billions)       1947 non-null   float64
#  7   Profits (Billions)       1947 non-null   float64
#  8   Assets (Billions)        1947 non-null   float64
#  9   Market Value (Billions)  1947 non-null   float64
#  10  Total Employees          1947 non-null   object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 182.5+ KB
